# %% [markdown]
# # Visualisation

# %%
import numpy as np
import matplotlib.pyplot as plt

img = np.random.randint(0, 255, size=(600, 800))
plt.imshow(img, cmap='gray')
plt.show()

# %%
img = np.random.randint(0, 255, size=(60, 80))
plt.imshow(img, cmap='hsv')
plt.show()
